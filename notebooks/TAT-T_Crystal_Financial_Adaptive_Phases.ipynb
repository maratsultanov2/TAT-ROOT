# %% [markdown]
# # TAT-T Crystal on Financial Data\n\nThis notebook reproduces the financial case study.\n\n**Full code is available in the TAT-ROOT repository.**

# %%
# Run the experiment (code from TAT-ROOT/TAT-T_Crystal_Financial_Adaptive_Phases.py)
