# %% [markdown]
# # TAT-7 Comparative Benchmark — Split Fashion-MNIST
# Воспроизводимый бенчмарк TAT-7 vs EWC/SI/MAS на continual learning.
# Запустите все ячейки последовательно.

# %%
# !pip install -q torch torchvision matplotlib pandas numpy
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
import torchvision.transforms as T
from torchvision import datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print('✅ Зависимости загружены')

# %%
# Загрузка данных и запуск бенчмарка
# (полный код из TAT-ROOT/data/)
print('См. полный код в TAT-ROOT/data/')
