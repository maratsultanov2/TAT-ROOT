# %% [markdown]
# # TAT-T Notebook
#
# This notebook reproduces the results described in the TAT-T documentation.
#
# **Full code** is available in the [TAT-ROOT repository](https://github.com/maratsultanov2/TAT-ROOT).
#
# For details, see the respective documentation:
# - [TAT-T Triumvirate](https://github.com/maratsultanov2/TAT-ROOT/blob/main/docs/en/TAT-T_TRIUMVIRATE.md)
# - [TAT-T Crystal Phase Selection](https://github.com/maratsultanov2/TAT-ROOT/blob/main/docs/en/TAT-T_CRYSTAL_PHASE_SELECTION.md)

# %%
print('Hello TAT-T')
